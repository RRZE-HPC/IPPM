# %%
from IPython.display import HTML
with open("custom/style.css", "r") as f:
    custom_style = f.read()
hide_cell_style = "<style>.jp-Cell:has(.hide-me) { display: yes; }</style>"
HTML(f"<div class='hide-me'></div><style>{custom_style}</style>{hide_cell_style}")
# Out:
# <div class='hide-me'></div><style>    /* works in JupyterLab */
#     :root {
#         --jp-content-font-size1: 24px !important;
#         --jp-code-font-size: 24px !important;
#     }
#     .jp-RenderedMarkdown, .rendered_html {
#         font-size: 24px !important;
#     }
#     h1 {font-size: 40px !important;}
#     h2 {font-size: 30px !important;}
#     p { font-size: 24px !important;}
#     /*
#     td {
#         padding: 10px;
#     }
#     */
#     .jp-RenderedHTMLCommon table,
#     .jp-RenderedHTMLCommon td,
#     .jp-RenderedHTMLCommon th,
#     .rendered_html table,
#     .rendered_html td,
#     .rendered_html th {
#         border: 2px solid black !important;
#         border-collapse: collapse !important;
#     }
#     .jp-RenderedHTMLCommon tr:nth-child(even),
#     .rendered_html tr:nth-child(even) {
#         background-color: #e2e2e2 !important;
#     }
#     /* Target ALL markdown code blocks */
#     .rendered_html pre {
# ...

# %% [markdown]
# <h1><center><font color='blue'>Introduction to Parallel Programming with MPI</font></center></h1>

# %% [markdown]
# ## General

# %% [markdown]
# <img src="figs/NHR-FAU-Logo.png" alt="NHR-FAU-Logo.png" style="float: right; margin-right: 50px;" width="30%">
# <!--```{image} figs/NHR-FAU-Logo.png
# :width: 300px
# ```-->
#
# This online course is designed for students and scientists with interest in parallel programming with MPI. It provides a thorough introduction to MPI, which is the most widespread parallelization paradigm in high performance computing (HPC).
#
# **Topics covered by this course:**
# - Basic principles of distributed-memory computer architecture and the Message Passing Interface (MPI)
# - Blocking and non-blocking point-to-point communication
# - Blocking and non-blocking collective communication
# - Derived data types
# - Subcommunicators, intercommunicators
# - Performance issues
#
# Exercises:
# - **9** exercises with a variety of difficulty
# - All exercises are already MPI parallel; however, they are <font color='red'>not compilable/runnable</font> because markers have been placed in the code. To solve the exercises, you are supposed to fix them by replacing the markers with correct code.
#
# **Lecturers:** Dr. Alireza Ghasemi and Dr. Georg Hager (NHR@FAU)

# %% [markdown]
# ## Timetable

# %% [markdown]
# <table style="border: 5px solid black; text-align: center; font-size:14pt; width:80%">
#   <tr>
#     <th style="text-align: center; background-color: powderblue; font-size:12pt" colspan="3">All times in this schedule are Central European Time (CET)</th>
#   </tr>
#   <tr>
#     <th style="text-align: center; color: white; background-color: darkblue; font-size:28pt" colspan="3">Day 1</th>
#   </tr>
#   <tr>
#     <th style="text-align: center; background-color: powderblue">Time</th><th style="text-align: center; background-color: powderblue">Topic</th><th style="text-align: center; background-color: powderblue"></th>
#   </tr>
#     <tr><td style="text-align: center">09:00-09:45</td><td style="text-align: center">Basics</td><td style="text-align: center">Beginners' set</td></tr>
#     <tr><td style="text-align: center">09:45-10:15</td><td style="text-align: center">Hands-on</td><td style="text-align: center">Hello+Pi</td></tr>
#     <tr><td style="text-align: center">10:15-10:30</td><td style="text-align: center">Break</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">10:30-11:00</td><td style="text-align: center">Point-to-Point (Blocking)</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">11:00-11:30</td><td style="text-align: center">Hands-on</td><td style="text-align: center">1D Jacobi (PtP Blocking)</td></tr>
#     <tr><td style="text-align: center">11:30-12:00</td><td style="text-align: center">Point-to-Point (Nonblocking)</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center; color: red">12:00-13:00</td><td style="text-align: center; color: red">Lunch</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">13:00-13:45</td><td style="text-align: center">Hands-on</td><td style="text-align: center">1D Jacobi (PtP Nonblocking)</td></tr>
#     <tr><td style="text-align: center">13:45-14:30</td><td style="text-align: center">Collectives (I)</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">14:30-15:00</td><td style="text-align: center">Hands-on</td><td style="text-align: center">1D Jacobi (Checkpoint)</td></tr>
#     <tr><td style="text-align: center">15:00-15:30</td><td style="text-align: center">Break</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">15:30-15:45</td><td style="text-align: center">Collectives (II)</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">15:45-16:00</td><td style="text-align: center">Hands-on</td><td style="text-align: center">Pi (Collective Ops.)</td></tr>
#     <tr><td style="text-align: center; color: red" colspan="3">Feierabend</td></tr>
# </table>
#
# <p></p>
#
# <table style="border: 5px solid black; text-align: center; font-size:14pt; width:80%">
#   <tr>
#     <th style="text-align: center; background-color: powderblue; font-size:12pt" colspan="3">All times in this schedule are Central European Time (CET)</th>
#   </tr>
#   <tr>
#     <th style="text-align: center; color: white; background-color: darkblue; font-size:28pt" colspan="3">Day 2</th>
#   </tr>
#   <tr>
#     <th style="text-align: center; background-color: powderblue">Time</th><th style="text-align: center; background-color: powderblue">Topic</th><th style="text-align: center; background-color: powderblue"></th>
#   </tr>
#     <tr><td style="text-align: center">09:00-09:20</td><td style="text-align: center">Collectives (Nonblocking)</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">09:20-09:45</td><td style="text-align: center">Hands-on</td><td style="text-align: center">1D Jacobi (Convergence)</td></tr>
#     <tr><td style="text-align: center">09:45-10:15</td><td style="text-align: center">Derived Datatypes</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">10:15-10:45</td><td style="text-align: center">Hands-on</td><td style="text-align: center">Subarray</td></tr>
#     <tr><td style="text-align: center">10:45-11:00</td><td style="text-align: center">Break</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">11:00-11:20</td><td style="text-align: center">Communicators</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">11:20-11:45</td><td style="text-align: center">Hands-on</td><td style="text-align: center">Comm. Split</td></tr>
#     <tr><td style="text-align: center; color: red">11:45-12:45</td><td style="text-align: center; color: red">Lunch</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">12:45-13:30</td><td style="text-align: center">Odds + Ends</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">13:30-14:00</td><td style="text-align: center">Basics of parallel computer architecture</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">14:00-14:30</td><td style="text-align: center">Affinity and pinning</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">14:30-14:50</td><td style="text-align: center">Break</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">14:50-15:20</td><td style="text-align: center">Simple scaling laws</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">15:20-15:40</td><td style="text-align: center">Benchmarking and performance assessment</td><td style="text-align: center"></td></tr>
#     <tr><td style="text-align: center">15:40-16:20</td><td style="text-align: center">Tracing tools + Hands-on</td><td style="text-align: center">Ray-Tracer</td></tr>
#     <tr><td style="text-align: center; color: red" colspan="3">Feierabend</td></tr>
# </table>

# %% [markdown]
# ## Misc info and links

# %% [markdown]
# - <u>[Intro video on the `make` tool (link to slides available below the video)](https://youtu.be/GJMJd8UawbM)</u>
#
# - <u>[Video on the DDT parallel debugger (link to slides is below video)](https://www.fau.tv/clip/id/19957)</u>
